# %%
import data_collect

get_date()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0a21bde94bdf> in <module>
#       1 import data_collect
#       2
# ----> 3 get_date()
#
# NameError: name 'get_date' is not defined

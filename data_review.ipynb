# %%
# Shows generic data downloaded from WHO

from data_collect import data_collect
import pandas
import csv

collection = data_collect()
collection.scrapeData()

all_pd = pandas.read_csv(collection.datf, sep=',', encoding='utf-8')
all_pd
# Out:
#       ï»¿Date_reported  Country_code      Country  WHO_region   New_cases  \
# 0           2020-02-24            AF  Afghanistan        EMRO           5
# 1           2020-02-25            AF  Afghanistan        EMRO           0
# 2           2020-02-26            AF  Afghanistan        EMRO           0
# 3           2020-02-27            AF  Afghanistan        EMRO           0
# 4           2020-02-28            AF  Afghanistan        EMRO           0
# ...                ...           ...          ...         ...         ...
# 38996       2020-08-29            ZW     Zimbabwe        AFRO          96
# 38997       2020-08-30            ZW     Zimbabwe        AFRO          18
# 38998       2020-08-31            ZW     Zimbabwe        AFRO           6
# 38999       2020-09-01            ZW     Zimbabwe        AFRO          85
# 39000       2020-09-02            ZW     Zimbabwe        AFRO          62
#
#         Cumulative_cases   New_deaths   Cumulative_deaths
# ...

# %%
# Shows plotted data from Republic of Korea (1.19 ~ 9.1)

from matplotlib import pyplot as plt

collection.showData()

# %%
# Shows a list of Countries with Covid19 Datasets
country_key = collection.get_country_list()
print(country_key)
# Out:
# ['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia (Plurinational State of)', 'Bonaire, Sint Eustatius and Saba', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands', 'Central African Republic', 'Chad', 'Chile', 'China', 'Colombia', 'Comoros', 'Congo', 'Costa Rica', 'CÃ´te dâ\x80\x99Ivoire', 'Croatia', 'Cuba', 'CuraÃ§ao', 'Cyprus', 'Czechia', 'Democratic Republic of the Congo', 'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia', 'Eswatini', 'Ethiopia', 'Falkland Islands (Malvinas)', 'Faroe Islands', 'Fiji', 'Finland', 'France', '
# ...
